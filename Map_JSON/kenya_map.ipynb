# %%
import geopandas as gpd 
import matplotlib.pyplot as plt

# %%
kenya_map = gpd.read_file("ke.json")
africa = gpd.read_file("/home/erickwambugu/Downloads/Africa.json")

# %%
fig, ax = plt.subplots(figsize=(15,15))
kenya_map.plot(ax=ax, color="lightblue", edgecolor="black")
plt.title("Map of Kenya", fontsize=15)
plt.savefig("kenya_map_output.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,15))
africa.plot(ax=ax, color="lightgreen", edgecolor="black")
plt.title("Map of Africa", fontsize=15)
plt.savefig("africa_map_output.png", dpi=300, bbox_inches='tight')
plt.show()
